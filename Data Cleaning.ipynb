# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("Dataset_1.csv")

# %%
df
# Out:
#             job_id                     company_name  \
# 0           921716            Corcoran Sawyer Smith
# 1          1829192                              NaN
# 2         10998357           The National Exemplar
# 3         23221523           Abrams Fensterman, LLP
# 4         35982263                              NaN
# ...            ...                              ...
# 123844  3906267117                     Lozano Smith
# 123845  3906267126                        Pinterest
# 123846  3906267131                     EPS Learning
# 123847  3906267195  Trelleborg Applied Technologies
# 123848  3906267224                        Solugenix
#
#                                                     title  \
# 0                                   Marketing Coordinator
# 1                       Mental Health Therapist/Counselor
# 2                             Assitant Restaurant Manager
# 3       Senior Elder Law / Trusts and Estates Associat...
# 4                                      Service Technician
# ...                                                   ...
# 123844                   Title IX/Investigations Attorney
# 123845       Staff Software Engineer, ML Serving Platform
# 123846               Account Executive, Oregon/Washington
# 123847                       Business Development Manager
# 123848                  Marketing Social Media Specialist
#
#                                               description  max_salary  \
# 0       Job descriptionA leading real estate firm in N...        20.0
# 1       At Aspen Therapy and Wellness , we are committ...        50.0
# 2       The National Exemplar is accepting application...     65000.0
# 3       Senior Associate Attorney - Elder Law / Trusts...    175000.0
# 4       Looking for HVAC service tech with experience ...     80000.0
# ...                                                   ...         ...
# 123844  Our Walnut Creek office is currently seeking a...    195000.0
# 123845  About Pinterest:\n\nMillions of people across ...         NaN
# 123846  Company Overview\n\nEPS Learning is a leading ...         NaN
# 123847  The Business Development Manager is a 'hunter'...         NaN
# 123848  Marketing Social Media Specialist - $70k – $75...     75000.0
#
#        pay_period                 location  company_id  views  min_salary  \
# 0          HOURLY            Princeton, NJ   2774458.0   20.0        17.0
# 1          HOURLY         Fort Collins, CO         NaN    1.0        30.0
# 2          YEARLY           Cincinnati, OH  64896719.0    8.0     45000.0
# 3          YEARLY        New Hyde Park, NY    766262.0   16.0    140000.0
# 4          YEARLY           Burlington, IA         NaN    3.0     60000.0
# ...           ...                      ...         ...    ...         ...
# 123844     YEARLY         Walnut Creek, CA     56120.0    1.0    120000.0
# 123845        NaN            United States   1124131.0    3.0         NaN
# 123846        NaN              Spokane, WA  90552133.0    3.0         NaN
# 123847        NaN     Texas, United States   2793699.0    4.0         NaN
# 123848     YEARLY  San Juan Capistrano, CA     43325.0    2.0     70000.0
#
#         ... applies  remote_allowed    application_type  \
# 0       ...     2.0             NaN  ComplexOnsiteApply
# 1       ...     NaN             NaN  ComplexOnsiteApply
# 2       ...     NaN             NaN  ComplexOnsiteApply
# 3       ...     NaN             NaN  ComplexOnsiteApply
# 4       ...     NaN             NaN  ComplexOnsiteApply
# ...     ...     ...             ...                 ...
# 123844  ...     NaN             NaN  ComplexOnsiteApply
# 123845  ...     NaN             1.0        OffsiteApply
# 123846  ...     NaN             1.0        OffsiteApply
# 123847  ...     NaN             1.0  ComplexOnsiteApply
# 123848  ...     NaN             NaN  ComplexOnsiteApply
#
#                                               skills_desc  \
# 0       Requirements: \n\nWe are seeking a College or ...
# 1                                                     NaN
# 2       We are currently accepting resumes for FOH - A...
# 3       This position requires a baseline understandin...
# 4                                                     NaN
# ...                                                   ...
# 123844                                                NaN
# 123845                                                NaN
# 123846                                                NaN
# 123847                                                NaN
# 123848                                                NaN
#
#                     posting_domain  work_type currency compensation_type  \
# 0                              NaN  FULL_TIME      USD       BASE_SALARY
# 1                              NaN  FULL_TIME      USD       BASE_SALARY
# 2                              NaN  FULL_TIME      USD       BASE_SALARY
# 3                              NaN  FULL_TIME      USD       BASE_SALARY
# 4                              NaN  FULL_TIME      USD       BASE_SALARY
# ...                            ...        ...      ...               ...
# 123844                         NaN  FULL_TIME      USD       BASE_SALARY
# 123845    www.pinterestcareers.com  FULL_TIME      NaN               NaN
# 123846  epsoperations.bamboohr.com  FULL_TIME      NaN               NaN
# 123847                         NaN  FULL_TIME      NaN               NaN
# 123848                         NaN  FULL_TIME      USD       BASE_SALARY
#
#        normalized_salary     fips
# 0                38480.0  34021.0
# 1                83200.0   8069.0
# 2                55000.0  39061.0
# 3               157500.0  36059.0
# 4                70000.0  19057.0
# ...                  ...      ...
# 123844          157500.0   6013.0
# 123845               NaN      NaN
# 123846               NaN  53063.0
# 123847               NaN      NaN
# 123848           72500.0   6059.0
#
# [123849 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# job_id                      0
# company_name             1719
# title                       0
# description                 7
# max_salary              94056
# pay_period              87776
# location                    0
# company_id               1717
# views                    1689
# min_salary              94056
# formatted_work_type         0
# applies                100529
# remote_allowed         108603
# application_type            0
# skills_desc            121410
# posting_domain          39968
# work_type                   0
# currency                87776
# compensation_type       87776
# normalized_salary       87776
# fips                    27415
# dtype: int64

# %%
# job_id                      0
# company_name             1719
# title                       0
# description                 7
# max_salary              94056
# pay_period              87776
# location                    0
# company_id               1717
# views                    1689
# min_salary              94056
# formatted_work_type         0
# applies                100529
# remote_allowed         108603
# application_type            0
# skills_desc            121410
# posting_domain          39968
# work_type                   0
# currency                87776
# compensation_type       87776
# normalized_salary       87776
# fips                    27415

# %%
df[["company_name"]].isnull().sum()
# Out:
# company_name    1719
# dtype: int64

# %%
df[["company_name"]].fillna("Unknown" )
# Out:
#                            company_name
# 0                 Corcoran Sawyer Smith
# 1                               Unknown
# 2                The National Exemplar
# 3                Abrams Fensterman, LLP
# 4                               Unknown
# ...                                 ...
# 123844                     Lozano Smith
# 123845                        Pinterest
# 123846                     EPS Learning
# 123847  Trelleborg Applied Technologies
# 123848                        Solugenix
#
# [123849 rows x 1 columns]

# %%
df[["company_name"]].isnull().sum()
# Out:
# company_name    1719
# dtype: int64
